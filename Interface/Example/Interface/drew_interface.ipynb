# %% [markdown]
# <i><font color="fuchsia" size=7>IoT Device Manager

# %% [markdown]
# This app allows to to view information from devices and control them.

# %%
# %run "Interface Code.ipynb"

# %%
#send("nile", "movePlunger(centris_pump)")
#shutdown("flow_1", hard=True)

# %%
# my_id ='db2bd247-a67d-4024-bbe9-2f8e2b9c8d51'
# mbb = messaging.MessageBroker(my_id)                             # spin up iot
# mbb.publish_message( topic=f"devices/dummy/flow_1", message={"command": "x='hello'","id":my_id} )    # send command to listening device
# mbb.shutdown()                                                             # shutdown iot

# %% [markdown]
# # <font color="SteelBlue">Device Controller

# %% [markdown]
# This tool allows you to to change what commands run on your device. It also allows you to pause experiments and shut them down when your done.

# %%
ctrl_device
# Out:
# HTML(value='<h4>Command sent to dinolite_1</h4>')
# Button(button_style='info', icon='refresh', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# # <font color="DarkOrchid"> Device Viewer

# %% [markdown]
# ## <font color="DarkOrchid"> Draw Schedule

# %%
cal_device
# Out:
# VBox(children=(HTML(value='<h3>Select Devices</h3><p>Type the name of the devices you wish to view.</p><p>Use …

# %% [markdown]
# ## <font color="DarkOrchid"> View History

# %%
hist_device
# Out:
# Button(button_style='info', icon='refresh', layout=Layout(width='auto'), style=ButtonStyle())
# HTML(value='<h3>History</h3><hr>')
# HTML(value='<p>2022-07-19 16:52:55 PDT - Run Command: take_photo( camera="/dev/video0", filename="every" )</p>…
# HTML(value='<p>2022-07-19 16:53:25 PDT -</p>')
# HTML(value='<p>Traceback (most recent call last):</p>')
# HTML(value='<p>  File "<string>", line 38, in respondToCommand</p>')
# HTML(value='<p>Exception: User message-- take_photo( camera="/dev/video0", filename="every" )-- received multi…
# HTML(value='<p></p>')
# HTML(value='<p>2022-07-19 16:57:35 PDT - Run Command: schedule.every(1).hours.until("2022-07-20 10:33").do( ta…
# HTML(value="<p>2022-07-19 17:57:35 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-19 18:57:38 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-19 19:57:41 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-19 20:57:43 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-19 21:57:46 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-19 22:57:49 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-19 23:57:52 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 00:57:54 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 01:57:57 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 02:58:00 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 03:58:03 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 04:58:06 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 05:58:09 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 06:58:12 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 07:58:14 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 08:58:17 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 09:58:20 PDT - Running job Job(interval=1, unit=hours, do=take_photo, args=(), kwarg…
# HTML(value="<p>2022-07-20 09:58:23 PDT - Cancelling job Job(interval=1, unit=hours, do=take_photo, args=(), kw…
# HTML(value='<p>2022-07-20 09:58:23 PDT - Cancelling job "Job(interval=1, unit=hours, do=take_photo, args=(), k…
